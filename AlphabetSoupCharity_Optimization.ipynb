# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# Drop the additional columns of 'STATUS' and 'SPECIAL_CONSIDERATIONS'
application_df = application_df.drop(columns = ["EIN", "NAME", "STATUS", "SPECIAL_CONSIDERATIONS"])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT   ASK_AMT  IS_SUCCESSFUL
# 0       Association              0      5000              1
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE      17
# AFFILIATION            6
# CLASSIFICATION        71
# USE_CASE               5
# ORGANIZATION           4
# INCOME_AMT             9
# ASK_AMT             8747
# IS_SUCCESSFUL          2
# dtype: int64

# %%
# Drop the 'ASK_AMT' column
application_df = application_df.drop(columns = ["ASK_AMT"])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION     INCOME_AMT  IS_SUCCESSFUL
# 0       Association              0              1
# ...

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE    17
# AFFILIATION          6
# CLASSIFICATION      71
# USE_CASE             5
# ORGANIZATION         4
# INCOME_AMT           9
# IS_SUCCESSFUL        2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df["APPLICATION_TYPE"].value_counts()
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_type_counts[application_type_counts<500].index)
cutoff_value = 700

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"OTHER")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# OTHER      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_value_counts = application_df["CLASSIFICATION"].value_counts()
classification_value_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_value_counts [classification_value_counts <1500].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"OTHER")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# OTHER     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df)
display(dummies_df.head())
display(dummies_df.tail())
# Out:
#    IS_SUCCESSFUL  APPLICATION_TYPE_OTHER  APPLICATION_TYPE_T10  \
# 0              1                       0                     1
# 1              1                       0                     0
# 2              0                       0                     0
# 3              1                       0                     0
# 4              1                       0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  \
# 0                    0                    0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dummies_df["IS_SUCCESSFUL"].values
X = dummies_df.drop(columns = "IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# FIRST Optimization Attempt - accuracy: 0.7255
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create a Keras Sequential model and add more than one Dense hidden layer
units_first_layer = 80
units_second_layer = 30
input_features = len(X_train_scaled[0])
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_first_layer, activation="relu", input_dim=input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_second_layer, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3200
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5661 (22.11 KB)
# Trainable params: 5661 (22.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# FIRST Optimization Attempt
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# FIRST Optimization Attempt
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 6s 5ms/step - loss: 0.5686 - accuracy: 0.7220
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5551 - accuracy: 0.7307
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7305
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5505 - accuracy: 0.7316
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7317
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5492 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7331
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7334
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5468 - accuracy: 0.7329
# Epoch 10/100
# ...

# %%
# FIRST Optimization Attempt
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5582 - accuracy: 0.7255 - 526ms/epoch - 2ms/step
# Loss: 0.5582166314125061, Accuracy: 0.7254810333251953

# %%
# SECOND Optimization Attempt - accuracy: 0.7250
# Increase the units in the first layer to 90
# Use "tanh" instead of "relu" as the activation function for both hidden layers
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create a Keras Sequential model and add more than one Dense hidden layer
units_first_layer = 90
units_second_layer = 30
input_features = len(X_train_scaled[0])
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_first_layer, activation="tanh", input_dim=input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_second_layer, activation="tanh"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 90)                3600
#
#  dense_4 (Dense)             (None, 30)                2730
#
#  dense_5 (Dense)             (None, 1)                 31
#
# ...
# Total params: 6361 (24.85 KB)
# Trainable params: 6361 (24.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# SECOND Optimization Attempt
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# SECOND Optimization Attempt
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5728 - accuracy: 0.7227
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5567 - accuracy: 0.7292
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7314
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7326
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5503 - accuracy: 0.7321
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7331
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5484 - accuracy: 0.7330
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7333
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7337
# Epoch 10/100
# ...

# %%
# SECOND Optimization Attempt
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5545 - accuracy: 0.7250 - 487ms/epoch - 2ms/step
# Loss: 0.5545487403869629, Accuracy: 0.7250145673751831

# %%
# THIRD Optimization Attempt - accuracy: 0.7266
# Leave the units in the first layer at 90
# Return to "relu" as the activation function for both hidden layers
# Change the activation function from "sigmoid" to "tanh" for the output layer
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create a Keras Sequential model and add more than one Dense hidden layer
units_first_layer = 90
units_second_layer = 30
input_features = len(X_train_scaled[0])
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_first_layer, activation="relu", input_dim=input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_second_layer, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation="tanh"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 90)                3600
#
#  dense_7 (Dense)             (None, 30)                2730
#
#  dense_8 (Dense)             (None, 1)                 31
#
# ...
# Total params: 6361 (24.85 KB)
# Trainable params: 6361 (24.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# THIRD Optimization Attempt
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# THIRD Optimization Attempt
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 1.0093 - accuracy: 0.6787
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6192 - accuracy: 0.7195
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.6152 - accuracy: 0.7112
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5852 - accuracy: 0.7268
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5889 - accuracy: 0.7126
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6155 - accuracy: 0.7165
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6008 - accuracy: 0.7209
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5785 - accuracy: 0.7234
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5654 - accuracy: 0.7292
# Epoch 10/100
# ...

# %%
# THIRD Optimization Attempt
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5716 - accuracy: 0.7266 - 476ms/epoch - 2ms/step
# Loss: 0.571644127368927, Accuracy: 0.7266472578048706

# %%
# FOURTH Optimization Attempt - accuracy: 0.7251
# Increase the units in the first layer to 100
# Increase the number of units in the second layer to 50
# Add a third layer with 25 units
# Use "relu" as the activation function for the hidden layers
# Use "sigmoid" as the activation function for the output layer
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Create a Keras Sequential model and add more than one Dense hidden layer
units_first_layer = 100
units_second_layer = 50
units_third_layer = 25
input_features = len(X_train_scaled[0])
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_first_layer, activation="relu", input_dim=input_features))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_second_layer, activation="relu"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units = units_third_layer, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 100)               4000
#
#  dense_10 (Dense)            (None, 50)                5050
#
#  dense_11 (Dense)            (None, 25)                1275
#
#  dense_12 (Dense)            (None, 1)                 26
#
# ...
# Total params: 10351 (40.43 KB)
# Trainable params: 10351 (40.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# FOURTH Optimization Attempt
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# FOURTH Optimization Attempt
# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5665 - accuracy: 0.7236
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7307
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5519 - accuracy: 0.7308
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5502 - accuracy: 0.7327
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7343
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5487 - accuracy: 0.7330
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5478 - accuracy: 0.7345
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5472 - accuracy: 0.7336
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5461 - accuracy: 0.7359
# Epoch 10/100
# ...

# %%
# FOURTH Optimization Attempt
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5585 - accuracy: 0.7251 - 497ms/epoch - 2ms/step
# Loss: 0.5585438013076782, Accuracy: 0.7251312136650085

# %%
# Export our model to HDF5 file
nn_model.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
